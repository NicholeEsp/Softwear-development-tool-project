# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars= pd.read_csv('../vehicles_us.csv')

# %%
display(cars)
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
# ...

# %%
display(cars.price.info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51525 entries, 0 to 51524
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 51525 non-null  int64
# dtypes: int64(1)
# memory usage: 402.7 KB
# None

# %%
display(cars.days_listed.info())
display(cars.days_listed.value_counts())
display(cars.days_listed.value_counts().sort_index())
display(cars.days_listed.value_counts().sort_index().plot( xlabel='Number of days on Market', ylabel='Number of vehicles',
                                                          title='How many days a vehicle had been listed for'))
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51525 entries, 0 to 51524
# Series name: days_listed
# Non-Null Count  Dtype
# --------------  -----
# 51525 non-null  int64
# dtypes: int64(1)
# memory usage: 402.7 KB
# None
# days_listed
# 18     959
# 24     950
# 22     945
# 19     941
# 20     934
#       ...
# 194      1
# 168      1
# 252      1
# 200      1
# 186      1
# Name: count, Length: 227, dtype: int64
# days_listed
# 0       54
# 1      173
# 2      259
# 3      384
# 4      438
#       ...
# 256      1
# 261      1
# 263      1
# 267      1
# 271      1
# Name: count, Length: 227, dtype: int64
# <Axes: title={'center': 'How many days a vehicle had been listed for'}, xlabel='Number of days on Market', ylabel='Number of vehicles'>

# %%
import numpy as np

# %%
condition=cars.condition

# %%
display(condition.isnull().sum())
# Out:
# np.int64(0)

# %%
display(condition.unique())
days_listed_count = cars.value_counts(subset=["condition", "days_listed"]).to_frame().reset_index()
days_listed_count.pivot(columns=["condition"], index=["days_listed"], values="count").plot.line(title='Length on market vs quality of car',
                        xlabel='Days Listed', ylabel='amount of cars')
# Out:
# array(['good', 'like new', 'fair', 'excellent', 'salvage', 'new'],
#       dtype=object)
# <Axes: title={'center': 'Length on market vs quality of car'}, xlabel='Days Listed', ylabel='amount of cars'>

# %% [markdown]
# <div class="alert alert-info">
# <h2> qulaity of car vs amount of cars on market</h2>
#
# Based on the chart above I am noticing that there is a peak for all cars no matter the condition that they are on the market for 25 days. From there there are still vehicles on the market but that there are less and less of them as time does on.
# </div>

# %%
cars['days_listed'].plot.hist(xlabel='days on market', ylabel='number of cars', title='car market time')
# Out:
# <Axes: title={'center': 'car market time'}, xlabel='days on market', ylabel='number of cars'>

# %%
display(cars['odometer'])
display(cars.odometer.info())
display(cars.odometer.value_counts())
display(cars.odometer.value_counts().sort_index())
# Out:
# 0        145000.0
# 1         88705.0
# 2        110000.0
# 3             NaN
# 4         80903.0
#            ...
# 51520     88136.0
# 51521    181500.0
# 51522    128000.0
# 51523    139573.0
# 51524         NaN
# Name: odometer, Length: 51525, dtype: float64
# <class 'pandas.core.series.Series'>
# RangeIndex: 51525 entries, 0 to 51524
# Series name: odometer
# Non-Null Count  Dtype
# --------------  -----
# 43633 non-null  float64
# dtypes: float64(1)
# memory usage: 402.7 KB
# None
# odometer
# 0.0         185
# 140000.0    183
# 120000.0    179
# 130000.0    178
# 160000.0    167
#            ...
# 47750.0       1
# 181645.0      1
# 105656.0      1
# 138608.0      1
# 129644.0      1
# Name: count, Length: 17762, dtype: int64
# odometer
# 0.0         185
# 1.0          28
# 2.0           2
# 3.0           1
# 5.0           9
#            ...
# 840000.0      2
# 866000.0      1
# 920000.0      1
# 980000.0      1
# 990000.0      2
# Name: count, Length: 17762, dtype: int64
